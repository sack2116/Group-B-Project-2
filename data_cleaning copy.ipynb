# %%
import pandas as pd

# %%
train_ds = pd.read_csv('./resources/train.csv')
test_ds = pd.read_csv('./resources/test.csv')
clean_ds = pd.read_csv('./resources/credit_score_cleaned_train.csv')
# Out:
# /var/folders/0g/m_btl88n5hs7w95j59p7v2180000gn/T/ipykernel_1150/2070022791.py:1: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_ds = pd.read_csv('./resources/train.csv')

# %%
display(train_ds.info())
display(clean_ds.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  object
#  1   Customer_ID               100000 non-null  object
#  2   Month                     100000 non-null  object
#  3   Name                      90015 non-null   object
#  4   Age                       100000 non-null  object
#  5   SSN                       100000 non-null  object
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  object
#  8   Monthly_Inhand_Salary     84998 non-null   float64
#  9   Num_Bank_Accounts         100000 non-null  int64
#  10  Num_Credit_Card           100000 non-null  int64
#  11  Interest_Rate             100000 non-null  int64
#  12  Num_of_Loan               100000 non-null  object
# ...

# %%
train_ds['Num_of_Delayed_Payment'].unique()
# Out:
# array(['7', nan, '4', '8_', '6', '1', '-1', '3_', '0', '8', '5', '3', '9',
#        '12', '15', '17', '10', '2', '2_', '11', '14', '20', '22', '13',
#        '13_', '14_', '16', '12_', '18', '19', '23', '24', '21', '3318',
#        '3083', '22_', '1338', '4_', '26', '11_', '3104', '21_', '25',
#        '10_', '183_', '9_', '1106', '834', '19_', '24_', '17_', '23_',
#        '2672', '20_', '2008', '-3', '538', '6_', '1_', '16_', '27', '-2',
#        '3478', '2420', '15_', '707', '708', '26_', '18_', '3815', '28',
#        '5_', '1867', '2250', '1463', '25_', '7_', '4126', '2882', '1941',
#        '2655', '2628', '132', '3069', '306', '0_', '3539', '3684', '1823',
#        '4128', '1946', '827', '2297', '2566', '904', '182', '929', '3568',
#        '2503', '1552', '2812', '1697', '3764', '851', '3905', '923', '88',
#        '1668', '3253', '808', '2689', '3858', '642', '3457', '1402',
#        '1732', '3154', '847', '3037', '2204', '3103', '1063', '2056',
# ...

# %%
clean_ds['credit_mix'].unique()
# Out:
# array(['Good', 'Standard', 'Bad'], dtype=object)

# %%
clean_ds[['occupation', 'type_of_loan', 'credit_mix', 'payment_of_min_amount', 'payment_behaviour']]
# Out:
#       occupation                                       type_of_loan  \
# 0      Scientist  ['Auto Loan', 'Credit-Builder Loan', 'Personal...
# 1      Scientist  ['Auto Loan', 'Credit-Builder Loan', 'Personal...
# 2      Scientist  ['Auto Loan', 'Credit-Builder Loan', 'Personal...
# 3      Scientist  ['Auto Loan', 'Credit-Builder Loan', 'Personal...
# 4      Scientist  ['Auto Loan', 'Credit-Builder Loan', 'Personal...
# ...          ...                                                ...
# 99995   Mechanic                      ['Auto Loan', 'Student Loan']
# 99996   Mechanic                      ['Auto Loan', 'Student Loan']
# 99997   Mechanic                      ['Auto Loan', 'Student Loan']
# 99998   Mechanic                      ['Auto Loan', 'Student Loan']
# 99999   Mechanic                      ['Auto Loan', 'Student Loan']
#
#       credit_mix payment_of_min_amount                 payment_behaviour
# 0           Good                    No   High_spent_Small_value_payments
# ...

# %%
print(clean_ds['payment_behaviour'].astype('category').cat.codes.unique())
print(clean_ds['payment_behaviour'].unique())
# Out:
# [2 3 4 5 1 0]
# ['High_spent_Small_value_payments' 'Low_spent_Large_value_payments'
#  'Low_spent_Medium_value_payments' 'Low_spent_Small_value_payments'
#  'High_spent_Medium_value_payments' 'High_spent_Large_value_payments']

# %%
clean_ds.describe(include="object").T
# Out:
#                         count  unique                             top   freq
# id                     100000  100000                          0x1602      1
# customer_id            100000   12500                       CUS_0xd40      8
# month                  100000       8                         January  12500
# name                   100000   10139                          Langep     48
# ssn                    100000   12500                     821-00-0265      8
# occupation             100000      15                          Lawyer   7096
# type_of_loan           100000    6261                     ['No Loan']  11408
# credit_mix             100000       3                        Standard  45848
# payment_of_min_amount  100000       2                             Yes  59432
# payment_behaviour      100000       6  Low_spent_Small_value_payments  27588
